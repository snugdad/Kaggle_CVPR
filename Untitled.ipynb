# %%
from PIL import Image
import matplotlib.pyplot as plt
from IPython.display import display
import numpy as np

c_im = Image.open("./store/train_color/170908_061523257_Camera_5.jpg")
l_im = Image.open("./store/train_label/170908_061523257_Camera_5_instanceIds.png")

#rgb_im = c_im.convert('RGB')

pixels = list(l_im.getdata())

print(pixels[1:10])
# Out:
# [255, 255, 255, 255, 255, 255, 255, 255, 255]

# %%
plt.imshow(c_im)

display(plt.show())
# Out:
# None

# %%
plt.imshow(l_im)
display(plt.show())
# Out:
# None

# %%
tlabel = np.asarray(Image.open("./store/train_label/170908_061523257_Camera_5_instanceIds.png"))//1000
tlabel[tlabel != 0] = 255
#plt.imshow(Image.blend(c_im, Image.fromarray(tlabel).convert('RGB'), alpha=0.6))
display(plt.show())
